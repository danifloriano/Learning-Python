# %% [markdown]
# Sintaxe:
# Print(Objetos, Argumentos)

# %%
mensagem = 'Função print()'
print(mensagem)
print('Aula de Python')
# Out:
# Função print()
# Aula de Python

# %%
nome = 'Daniel Floriano de Lima'
print('Nome completo -', nome)
# Out:
# Nome completo - Daniel Floriano de Lima

# %%
nome = 'Daniel Floriano de Lima'
tipo = 'Nome completo'
print(tipo, '-', nome)
# Out:
# Nome completo - Daniel Floriano de Lima

# %%
#concatenar strings
Nome = input('Digite o seu nome: ')
print('Olá ' + Nome + ' Seja bem-vindo!')
# Out:
# Olá Daniel Seja bem-vindo!

# %%
#concatenar strings
Nome = input('Digite o seu nome: ')
msg = 'Olá ' + Nome + ' Seja bem-vindo!'
print(msg)
print('Outro texto')
# Out:
# Olá Daniel Seja bem-vindo!
# Outro texto

# %%
print('Imprime a mensagem e muda de linha')
print('imprime a mensagem e permanece na linha...',end='')
print(' continuo na mesma linha!')
# Out:
# Imprime a mensagem e muda de linha
# imprime a mensagem e permanece na linha... continuo na mesma linha!

# %%
nome = 'Maria'
idade = 30
msg_formatada = 'O nome dela é {0} e ela tem {1} anos'.format(nome,idade)
print(msg_formatada)
# Out:
# O nome dela é Maria e ela tem 30 anos

# %% [markdown]
# format

# %%
nome = 'Maria'
idade = 30
print('O nome dela é {0} e ela tem {1} anos'.format(nome,idade))
# Out:
# O nome dela é Maria e ela tem 30 anos

# %% [markdown]
# f-string

# %%
nome = 'Daniel'
peso = 65.80
msg = f'Olá, o meu nome é {nome} e eu peso {peso} quilos'
print(msg)
# Out:
# Olá, o meu nome é Daniel e eu peso 65.8 quilos

# %%
nome = 'Daniel'
peso = 65.80
print(f'Olá, o meu nome é {nome} e eu peso {peso} quilos')
# Out:
# Olá, o meu nome é Daniel e eu peso 65.8 quilos

# %%
a = 10
b = 8
print(f'A soma de {a} com {b} é igual a {a+b}')
# Out:
# A soma de 10 com 8 é igual a 18

# %%
valor = 16166.54813
print(f'O valor é {valor:.2f}')
# Out:
# O valor é 16166.55

# %%
nome = 'João'
idade = 32
print(f'Nome:{nome}\tIdade:{idade}')
# Out:
# Nome:João	Idade:32

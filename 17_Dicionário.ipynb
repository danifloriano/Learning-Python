# %%
elemento = {
    'Z': 3,
    'nome':'Lítio',
    'grupo':'Metais alcalinos',
    'densidade':0.534
}
print(f'Elemento: {elemento['nome']}')
print(f'Densidade: {elemento['densidade']}')
print(f'O dicionário possui {len(elemento)} elementos.')
# Out:
# Elemento: Lítio
# Densidade: 0.534
# O dicionário possui 4 elementos.

# %%
#atualizar uma entrada
elemento['grupo'] = 'Alcalinos'
print(elemento)
# Out:
# {'Z': 3, 'nome': 'Lítio', 'grupo': 'Alcalinos', 'densidade': 0.534}

# %%
#Adicionar uma entrada
elemento['período'] = 1
print(elemento)
# Out:
# {'Z': 3, 'nome': 'Lítio', 'grupo': 'Alcalinos', 'densidade': 0.534, 'período': 1}

# %%
# exclusão de itens em dicionários
del elemento['período']
print(elemento)
# Out:
# {'Z': 3, 'nome': 'Lítio', 'grupo': 'Alcalinos', 'densidade': 0.534}

# %%
#excluir totalmente
elemento.clear()
print(elemento)
# Out:
# {}

# %%
#excluir dicionário
# del elemento
# print(elemento)

# %%
print(elemento.items())
for i in elemento.items():
    print(i)
# Out:
# dict_items([('Z', 3), ('nome', 'Lítio'), ('grupo', 'Metais alcalinos'), ('densidade', 0.534)])
# ('Z', 3)
# ('nome', 'Lítio')
# ('grupo', 'Metais alcalinos')
# ('densidade', 0.534)

# %%
print(elemento.keys())
for i in elemento.keys():
    print(i)
# Out:
# dict_keys(['Z', 'nome', 'grupo', 'densidade'])
# Z
# nome
# grupo
# densidade

# %%
print(elemento.values())
for i in elemento.values():
    print(i)
# Out:
# dict_values([3, 'Lítio', 'Metais alcalinos', 0.534])
# 3
# Lítio
# Metais alcalinos
# 0.534

# %%
for i, j in elemento.items():
    print(f'{i}: {j}')
# Out:
# Z: 3
# nome: Lítio
# grupo: Metais alcalinos
# densidade: 0.534

# %%
import os

# %%
os.name
# Out:
# 'nt'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\DaniF\\Desktop\\Python'

# %%
os.curdir
# Out:
# '.'

# %%
os.listdir()
# Out:
# ['10_modulos.ipynb',
#  '11_aleatorios.ipynb',
#  '12_Listas.ipynb',
#  '13_Exercício Listas.ipynb',
#  '14_Tuplas.ipynb',
#  '15_Funções Matematica.ipynb',
#  '16_Manipulação de Strings.ipynb',
#  '17_Dicionário.ipynb',
#  '18_Sets (Conjuntos).ipynb',
#  '19_Funções.ipynb',
#  '1_Variáveis.ipynb',
#  '20_Funções Parametros.ipynb',
#  '21_Escopo de Variaveis Global e Local.ipynb',
#  '22_Tratamento de Excessões.ipynb',
#  '23_Excessões raise.ipynb',
#  '24_Funções Recursivas.ipynb',
#  '25_Funções especiais.ipynb',
#  '26_List Comprehension.ipynb',
#  '27_POO.ipynb',
#  '28_Módulo OS.ipynb',
#  '2_Operadores Aritméticos.ipynb',
#  '3_Operadores de Comparação.ipynb',
#  '4_Operadores Lógicos.ipynb',
#  '5_Condicionais.ipynb',
#  '6_função print format f-string.ipynb',
#  '7_Laços de Repetição While.ipynb',
#  '8_Laço de repetição for e range.ipynb',
#  '9_Laços de repetição encadeados.ipynb',
#  'mod_func.py',
#  '__pycache__']

# %%
os.listdir('C://')
# Out:
# ['$Recycle.Bin',
#  '.GamingRoot',
#  'AMD',
#  'Arquivos de Programas',
#  'Cakewalk Content',
#  'Cakewalk Projects',
#  'Config.Msi',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'logUploaderSettings.ini',
#  'logUploaderSettings_temp.ini',
#  'MS OFFICE TOOL',
#  'OEM',
#  'OneDriveTemp',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Python DSA',
#  'PythonDSA',
#  'Recovery',
#  'Riot Games',
#  'SQL',
#  'SQL2022',
#  'swapfile.sys',
#  'System Volume Information',
#  'Users',
#  'Windows',
#  'XboxGames']

# %%
os.chdir('C:\\')

# %%
os.getcwd()
# Out:
# 'C:\\'

# %%
# criar pasta
os.mkdir('Teste')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 # criar pasta
# ----> 2 os.mkdir('Teste')
#
# FileExistsError: [WinError 183] Não é possível criar um arquivo já existente: 'Teste'

# %%
os.listdir()
# Out:
# ['$Recycle.Bin',
#  '.GamingRoot',
#  'AMD',
#  'Arquivos de Programas',
#  'Cakewalk Content',
#  'Cakewalk Projects',
#  'Config.Msi',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'logUploaderSettings.ini',
#  'logUploaderSettings_temp.ini',
#  'MS OFFICE TOOL',
#  'OEM',
#  'OneDriveTemp',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Python DSA',
#  'PythonDSA',
#  'Recovery',
#  'Riot Games',
#  'SQL',
#  'SQL2022',
#  'swapfile.sys',
#  'System Volume Information',
#  'Teste',
#  'Users',
#  'Windows',
#  'XboxGames']

# %%
os.chdir('Teste')

# %%
os.getcwd()
# Out:
# 'C:\\Teste'

# %%
pasta_nova = 'TEste2'

# %%
pasta_pai = 'C:\\'

# %%
caminho_completo = os.path.join(pasta_pai, pasta_nova)

# %%
print(caminho_completo)
# Out:
# C:\TEste2

# %%
os.mkdir(caminho_completo)

# %%
os.listdir('C:\\')
# Out:
# ['$Recycle.Bin',
#  '.GamingRoot',
#  'AMD',
#  'Arquivos de Programas',
#  'Cakewalk Content',
#  'Cakewalk Projects',
#  'Config.Msi',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'logUploaderSettings.ini',
#  'logUploaderSettings_temp.ini',
#  'MS OFFICE TOOL',
#  'OEM',
#  'OneDriveTemp',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Python DSA',
#  'PythonDSA',
#  'Recovery',
#  'Riot Games',
#  'SQL',
#  'SQL2022',
#  'swapfile.sys',
#  'System Volume Information',
#  'Teste',
#  'TEste2',
#  'Users',
#  'Windows',
#  'XboxGames']

# %%
os.rename('C:\\TEste2','C:\\Teste10')

# %%
os.listdir('C:\\')
# Out:
# ['$Recycle.Bin',
#  '.GamingRoot',
#  'AMD',
#  'Arquivos de Programas',
#  'Cakewalk Content',
#  'Cakewalk Projects',
#  'Config.Msi',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'logUploaderSettings.ini',
#  'logUploaderSettings_temp.ini',
#  'MS OFFICE TOOL',
#  'OEM',
#  'OneDriveTemp',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Python DSA',
#  'PythonDSA',
#  'Recovery',
#  'Riot Games',
#  'SQL',
#  'SQL2022',
#  'swapfile.sys',
#  'System Volume Information',
#  'Teste',
#  'Teste10',
#  'Users',
#  'Windows',
#  'XboxGames']

# %%
os.rmdir('C:\\Teste10')

# %%
os.listdir('C:\\')
# Out:
# ['$Recycle.Bin',
#  '.GamingRoot',
#  'AMD',
#  'Arquivos de Programas',
#  'Cakewalk Content',
#  'Cakewalk Projects',
#  'Config.Msi',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'logUploaderSettings.ini',
#  'logUploaderSettings_temp.ini',
#  'MS OFFICE TOOL',
#  'OEM',
#  'OneDriveTemp',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Python DSA',
#  'PythonDSA',
#  'Recovery',
#  'Riot Games',
#  'SQL',
#  'SQL2022',
#  'swapfile.sys',
#  'System Volume Information',
#  'Teste',
#  'Users',
#  'Windows',
#  'XboxGames']

# %%
os.path.basename(os.getcwd())
# Out:
# 'Teste'

# %%
os.path.dirname(os.getcwd())
# Out:
# 'C:\\'

# %%
pasta_pai = os.getcwd()

# %%
novas_pastas = 'América\\Brasil\\Ilhabela'

# %%
caminho = os.path.join(pasta_pai, novas_pastas)

# %%
print(caminho)
# Out:
# C:\Teste\América\Brasil\Ilhabela

# %%
os.makedirs(caminho)

# %%
os.path.exists('C:\\Teste\\América')
# Out:
# True

# %%
os.path.exists('C:\\Teste\\Asia')
# Out:
# False

# %%
os.path.isdir('C:\\Teste')
# Out:
# True

# %%
os.path.isfile('C:\\Teste')
# Out:
# False

# %%
os.getcwd()
# Out:
# 'C:\\Teste'

# %%
manipulador = open('arq.txt','x')

# %%
manipulador.close()

# %%
os.listdir()
# Out:
# ['América', 'arq.txt']

# %%
arquivo = os.path.basename('C:\\Teste\\arq.txt')

# %%
print(arquivo)
# Out:
# arq.txt

# %%
os.path.splitext(arquivo)
# Out:
# ('arq', '.txt')

# %%
os.remove('arq.txt')

# %%
os.listdir()
# Out:
# ['América']

# %%
import pathlib

# %%
caminho = pathlib.Path()

# %%
caminho.cwd()
# Out:
# WindowsPath('C:/Teste')

# %%
import os

# %%
os.rmdir('C:\\Teste')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 os.rmdir('C:\\Teste')
#
# PermissionError: [WinError 32] O arquivo já está sendo usado por outro processo: 'C:\\Teste'

# %%
import shutil
shutil.rmtree('C:\\Teste')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[68], line 2
#       1 import shutil
# ----> 2 shutil.rmtree('C:\\Teste')
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:790, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     788     # can't continue even if onexc hook returns
#     789     return
# --> 790 return _rmtree_unsafe(path, onexc)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:635, in _rmtree_unsafe(path, onexc)
#     633     pass
#     634 except OSError as err:
# --> 635     onexc(os.rmdir, path, err)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\shutil.py:631, in _rmtree_unsafe(path, onexc)
#     629             onexc(os.unlink, fullname, err)
#     630 try:
# --> 631     os.rmdir(path)
#     632 except FileNotFoundError:
#     633     pass
#
# PermissionError: [WinError 32] O arquivo já está sendo usado por outro processo: 'C:\\Teste'

# %%
import os

# %%
os.rmdir('C:\\Teste')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 os.rmdir('C:\\Teste')
#
# PermissionError: [WinError 32] O arquivo já está sendo usado por outro processo: 'C:\\Teste'

# %%
import os

os.chdir('C:\\Teste')
print(f'Diretório atual: {os.getcwd()}')

padrao_nome = input('Qual o padrão de nomes de arquivos a usar (sem a extensão)')

for contador, arq in enumerate(os.listdir()):
    if os.path.isfile(arq):
        nome_arq, exten_arq = os.path.splitext(arq)
        nome_arq = padrao_nome + ' ' + str(contador)

        nome_novo = f'{nome_arq}{exten_arq}'
        os.rename(arq, nome_novo)
        
print(f'\nArquivos renomeados.')
# Out:
# Diretório atual: C:\Teste
#
# Arquivos renomeados.

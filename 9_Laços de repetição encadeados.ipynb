# %%
for cont_ex in range(1,6):
    print(f'\nRodada: {cont_ex}')
    for cont_in in range(5,0,-1):
        print(f'Valor: {cont_in}')
print('Fim dos laços')
# Out:
# Rodada: 1
# Valor: 5
# Valor: 4
# Valor: 3
# Valor: 2
# Valor: 1
#
# Rodada: 2
# Valor: 5
# Valor: 4
# Valor: 3
# Valor: 2
# Valor: 1
#
# Rodada: 3
# Valor: 5
# Valor: 4
# Valor: 3
# Valor: 2
# Valor: 1
#
# Rodada: 4
# Valor: 5
# Valor: 4
# Valor: 3
# Valor: 2
# Valor: 1
#
# Rodada: 5
# Valor: 5
# Valor: 4
# Valor: 3
# Valor: 2
# Valor: 1
# Fim dos laços

# %%
import random

for A in range(1,6):
    print(f'\nConjunto {A}')
    for B in range(5):
        num = random.randint(1,100)
        print(f'Valor: {num}')
# Out:
# Conjunto 1
# Valor: 13
# Valor: 8
# Valor: 23
# Valor: 98
# Valor: 36
#
# Conjunto 2
# Valor: 20
# Valor: 24
# Valor: 52
# Valor: 23
# Valor: 29
#
# Conjunto 3
# Valor: 9
# Valor: 42
# Valor: 89
# Valor: 56
# Valor: 7
#
# Conjunto 4
# Valor: 20
# Valor: 10
# Valor: 99
# Valor: 27
# Valor: 58
#
# Conjunto 5
# Valor: 68
# Valor: 98
# Valor: 34
# Valor: 19
# Valor: 38

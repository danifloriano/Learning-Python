# %% [markdown]
# São imutavéis

# %%
tupla = (2,4,6,5,7,8)
print(tupla)
# Out:
# (2, 4, 6, 5, 7, 8)

# %%
halogenios = ('F','Cl','Br','I','At')
print(halogenios[-1])
# Out:
# At

# %%
halogenios = ('F','Cl','Br','I','At')
gases_nobres = ('He','Ne','Ar','Xe','Kr','Rn')
elementos = halogenios + gases_nobres
t1 = (1,8,15,89,5,5,2,3,6,9,8,5,4,22,5,9)
print(elementos)
print(t1.count(1))
print(halogenios[0:4])
print(halogenios[-2:])
print(max(t1))
# Out:
# ('F', 'Cl', 'Br', 'I', 'At', 'He', 'Ne', 'Ar', 'Xe', 'Kr', 'Rn')
# 1
# ('F', 'Cl', 'Br', 'I')
# ('I', 'At')
# 89

# %% [markdown]
# Operações não disponíveis em tuplas: operações que alteram sua estrutura
#
# .sort()
#
# .append()
#
# .reverse()
#
# .pop()

# %%
for elemento in elementos:
    print(f'Elemento químico: {elemento}')
# Out:
# Elemento químico: F
# Elemento químico: Cl
# Elemento químico: Br
# Elemento químico: I
# Elemento químico: At
# Elemento químico: He
# Elemento químico: Ne
# Elemento químico: Ar
# Elemento químico: Xe
# Elemento químico: Kr
# Elemento químico: Rn

# %%
grupo17 = list(halogenios)
print(grupo17)
# Out:
# ['F', 'Cl', 'Br', 'I', 'At']

# %%
#criando uma lista com tupla
grupo17 = list(halogenios)
grupo17[0] = 'H'
print(grupo17)
# Out:
# ['H', 'Cl', 'Br', 'I', 'At']

# %%
#criando tupla com lista
grupo1 = ['Li','Na','K','Rb','Cs','Fr']
alcalinos = tuple(grupo1)
print(type(alcalinos))
print(alcalinos)
print(sorted(alcalinos))
# Out:
# <class 'tuple'>
# ('Li', 'Na', 'K', 'Rb', 'Cs', 'Fr')
# ['Cs', 'Fr', 'K', 'Li', 'Na', 'Rb']

# %%
nome = 'Daniel'
letra = nome[2]
print(letra)
print(len(nome))
# Out:
# n
# 6

# %%
nome =  'Curso de Python'
aluno = 'Daniel'
print(nome + ' com ' + aluno)
print(len(nome + aluno))
# Out:
# Curso de Python com Daniel
# 21

# %%
frase = 'Vamos aprender Python hoje'
palavras = frase.split()
print(palavras)

for palavra in palavras:
    print(palavra)
    print(palavra[1])
# Out:
# ['Vamos', 'aprender', 'Python', 'hoje']
# Vamos
# a
# aprender
# p
# Python
# y
# hoje
# o

# %%
for letra in frase:
    print(letra)
# Out:
# V
# a
# m
# o
# s
#
# a
# p
# r
# e
# n
# d
# e
# r
#
# P
# y
# t
# h
# o
# n
#
# h
# o
# j
# e

# %%
frase = 'Vamos aprender Python hoje'
print(frase[-4:])
# Out:
# hoje

# %%
email = input('Digite o seu endereço de email: ')
arroba = email.find('@')
print(arroba)
usuario = email[0:arroba]
dominio = email[arroba+1:]
print(usuario)
print(dominio)
# Out:
# 13
# dani.floriano
# live.com

# %%
produtos = 'Carbonato de sódio e óxido de zinco'
print('sódio' in produtos)
print('magnésio' not in produtos)
# Out:
# True
# True

# %%
item = 'hipoclorito'
pos = item.find('clor')
print(pos)
pos = item.find('flu')
print(pos)
# Out:
# 4
# -1

# %%
objeto_celeste = 'galáxia espiral M31'
print(objeto_celeste.lower())
print(objeto_celeste.upper())
print(objeto_celeste.capitalize())
print(objeto_celeste.title())
# Out:
# galáxia espiral m31
# GALÁXIA ESPIRAL M31
# Galáxia espiral m31
# Galáxia Espiral M31

# %%
suplemento = 'cloreto de magnésio'
n_suplemento = suplemento.replace('magnésio','zinco')
print(suplemento)
print(n_suplemento)
# Out:
# cloreto de magnésio
# cloreto de zinco

# %%
frase = '     Deus é o meu juiz       '
print(frase)
print(frase.lstrip())
print(frase.rstrip())
print(frase.strip())
# Out:
#      Deus é o meu juiz
# Deus é o meu juiz
#      Deus é o meu juiz
# Deus é o meu juiz

# %%
fruta = 'Maracujá'
print(fruta)
print(fruta.rjust(20))
print(fruta.center(20))
print(fruta.ljust(20))
print(fruta.ljust(20,'-'))
print(fruta.center(20,'-'))
# Out:
# Maracujá
#             Maracujá
#       Maracujá
# Maracujá
# Maracujá------------
# ------Maracujá------

# %%
p = 'Daniel FLoriano de Lima'
print(p.startswith('D'))
print(p.endswith('a'))
# Out:
# True
# True

# %%
#Docstrings
texto = '''
Docstring é uma especie de documentação
que podemos inserir dentro de um módulo,
função ou classe no Python, entre outros 
locais.
    respeita deslocamento do texto e é 
    multilinhas
'''
print(texto)
# Out:
# Docstring é uma especie de documentação
# que podemos inserir dentro de um módulo,
# função ou classe no Python, entre outros
# locais.
#     respeita deslocamento do texto e é
#     multilinhas

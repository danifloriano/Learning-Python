# %%
#trocar valores entre duas variáveis

var1 = 12
var2 = 31

var2, var1 = var1, var2

print(f'var1: {var1}, var2: {var2}')
# Out:
# var1: 31, var2: 12

# %%
#Operador condicional ternário
var1 = 12
var2 = 31

menor = var1 if var1 < var2 else var2
print(f'Menor valor: {menor}')
print(f'Menor valor: {(var2, var1)[var1 < var2]}')
# Out:
# Menor valor: 12
# Menor valor: 12

# %%
#Generators
valores = [1,3,5,7,9,11,13,15]
quadrados = (item**2 for item in valores)
print(quadrados)
for valor in quadrados:
    print(valor)
# Out:
# <generator object <genexpr> at 0x0000029B83B55B10>
# 1
# 9
# 25
# 49
# 81
# 121
# 169
# 225

# %%
#função enumerate()
bebidas = ['Café','Chá','Água','Suco','Refrigerante']
for i, item in enumerate(bebidas):
    print(f'índice: {i}, Item: {item}')
# Out:
# índice: 0, Item: Café
# índice: 1, Item: Chá
# índice: 2, Item: Água
# índice: 3, Item: Suco
# índice: 4, Item: Refrigerante

# %%
temperaturas = [-1,10,6,35,19,-5,26]
total = 0
for i, t in enumerate(temperaturas):
    if t < 0:
        total += 1
print(f'Há {total} temperaturas negativas na amostra.')
# Out:
# Há 2 temperaturas negativas na amostra.
# A temperatura em 6 é negativa com 26°C.

# %%
temperaturas = [-1,10,6,35,19,-5,26]
total = 0
for i, t in enumerate(temperaturas):
    if t < 0:
        print(f'A temperatura em {i} é negativa com {t}°C.')
# Out:
# A temperatura em 0 é negativa com -1°C.
# A temperatura em 5 é negativa com -5°C.

# %%
#Gerenciamento de contexto com with

with open('frutas.txt','r',encoding='utf-8') as a:
    for linha in a:
        print(linha, end='')
# Out:
# Morango
# Uva
# Caju
# Amora
# Framboesa
# Maracujá

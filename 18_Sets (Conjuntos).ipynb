# %%
planeta_anao = {'PLutão','Ceres','Eris','Humea','Makemake'}
print(planeta_anao)
print(len(planeta_anao))
print('Lua' in planeta_anao)
print('Lua' not in planeta_anao)
# Out:
# {'Makemake', 'Humea', 'Ceres', 'PLutão', 'Eris'}
# 5
# False
# True

# %%
for astro in planeta_anao:
    print(astro.upper())
# Out:
# MAKEMAKE
# HUMEA
# CERES
# PLUTÃO
# ERIS

# %%
astros = ['Lua','Vênus','Sirius','Marte','Lua']
print(astros, end=' ')
astro_set = set(astros)
print(astro_set)
# Out:
# ['Lua', 'Vênus', 'Sirius', 'Marte', 'Lua'] {'Sirius', 'Lua', 'Marte', 'Vênus'}

# %%
astros1 = {'Lua','Vênus','Sirius','Marte','Lua','Io'}
astros2 = {'Lua','Vênus','Sirius','Marte','Lua','Cometa Halley'}
print(astros1 == astros2)

print(astros1 | astros2)
print(astros1.union(astros2))

print(astros1 & astros2)
print(astros1.intersection(astros2))

print(astros1 ^ astros2)
print(astros1.symmetric_difference(astros2))
# Out:
# False
# {'Cometa Halley', 'Io', 'Sirius', 'Marte', 'Vênus', 'Lua'}
# {'Cometa Halley', 'Io', 'Sirius', 'Marte', 'Vênus', 'Lua'}
# {'Sirius', 'Lua', 'Marte', 'Vênus'}
# {'Sirius', 'Lua', 'Marte', 'Vênus'}
# {'Io', 'Cometa Halley'}
# {'Io', 'Cometa Halley'}

# %%
astros1.add('Urano')
astros1.add('Sol')
print(astros1)
# Out:
# {'Sirius', 'Marte', 'Vênus', 'Lua', 'Sol', 'Urano'}

# %%
astros1.remove('Io')
print(astros1)
# Out:
# {'Lua', 'Sirius', 'Marte', 'Vênus'}

# %%
astros1.remove('Lua')
print(astros1)
# Out:
# {'Sirius', 'Marte', 'Vênus'}

# %%
astros.pop()
# Out:
# 'Lua'

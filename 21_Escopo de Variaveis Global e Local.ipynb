# %%
var_global = 'SPFC, o Clube da Fé'

def escreve_texto():
    var_local = 'Daniel FLoriano'
    print(f'Variável Global: {var_global}')
    print(f'Variável Local: {var_local}')

if __name__ == '__main__':
    print(f'Executar a função escreve_texto()')
    escreve_texto()

    print('Tentar acessar as variaveis diretamente')
    print(f'Variável Global: {var_global}')
# Out:
# Executar a função escreve_texto()
# Variável Global: SPFC, o Clube da Fé
# Variável Local: Daniel FLoriano
# Tentar acessar as variaveis diretamente
# Variável Global: SPFC, o Clube da Fé

# %%
var_global = 'SPFC, o Clube da Fé'

def escreve_texto():
    global var_global
    var_global = 'Monty Python'
    var_local = 'Daniel FLoriano'
    print(f'Variável Global: {var_global}')
    print(f'Variável Local: {var_local}')

if __name__ == '__main__':
    print(f'Executar a função escreve_texto()')
    escreve_texto()

    print('Tentar acessar as variaveis diretamente')
    print(f'Variável Global: {var_global}')
# Out:
# Executar a função escreve_texto()
# Variável Global: Monty Python
# Variável Local: Daniel FLoriano
# Tentar acessar as variaveis diretamente
# Variável Global: Monty Python
